# %% [markdown]
# # 50 Consecutive prime sum
#
# <p>The prime 41, can be written as the sum of six consecutive primes:</p>
# <div class="center">41 = 2 + 3 + 5 + 7 + 11 + 13</div>
# <p>This is the longest sum of consecutive primes that adds to a prime below one-hundred.</p>
# <p>The longest sum of consecutive primes below one-thousand that adds to a prime, contains 21 terms, and is equal to 953.</p>
# <p>Which prime, below one-million, can be written as the sum of the most consecutive primes?</p>

# %%
def fp(n):
    x = int(n**0.5)
    p = set()
    ps = {x: True for x in range(1, n+1)}
    ps[1] = False
    
    for X in range(2, x+1):
        y = 2*X
        while y <= n:
            ps[y] = False
            y += X
            
    psf = {key: value for (key, value) in ps.items() if value is not False}
    return list(psf.keys())

# %%
primes = fp(1_000_000)

# %%
sum(primes[:24])
# Out:
# 963

# %%
for x in map([1,2,3,4],["a","b","c"]):
    print(x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [38], in <cell line: 1>()
# ----> 1 for x in map([1,2,3,4],["a","b","c"]):
#       2     print(x)
#
# TypeError: 'list' object is not callable

# %%
r = list()
for i, x in enumerate(primes):
    r.append(map(x, primes[:i])

# %%
for i, prime in enumerate(primes):
    # print(i, prime, sum(primes[:i+1]), sum(primes[:i+1]) in primes)
    if sum(primes[:i+1]) in primes:
        print(sum(primes[:i+1]))
# Out:
# 2
# 5
# 17
# 41
# 197
# 281
# 7699
# 8893
# 22039
# 24133
# 25237
# 28697
# 32353
# 37561
# 38921
# 43201
# 44683
# 55837
# 61027
# 66463
# 70241
# 86453
# 102001
# 109147
# 116533
# 119069
# 121631
# 129419
# 132059
# 263171
# 287137
# 325019
# 329401
# 333821
# 338279
# 342761
# 360979
# 379667
# 393961
# 398771
# 581921
# 642869
# 681257
# 687767
# 700897
# 754573
# 768373
# 782263
# 868151
# 935507
# 958577
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [25], in <cell line: 1>()
#       1 for i, prime in enumerate(primes):
#       2     # print(i, prime, sum(primes[:i+1]), sum(primes[:i+1]) in primes)
# ----> 3     if sum(primes[:i+1]) in primes:
#       4         print(sum(primes[:i+1]))
#
# KeyboardInterrupt:
